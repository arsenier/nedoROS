# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /Users/bw/Documents/Hachathons/ROS2026

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8m.pt data=/Users/bw/Documents/Hachathons/ROS2026/top_view_toys/data.yaml epochs=100 imgsz=224
# Out:
# /Users/bw/Documents/Hachathons/ROS2026
# New https://pypi.org/project/ultralytics/8.4.24 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.23 🚀 Python-3.12.10 torch-2.10.0 CPU (Apple M1)
# ...

# %%
# %cd {HOME}

# !yolo task=detect mode=val model=/Users/bw/Documents/Hachathons/ROS2026/runs/detect/train19/weights/best.pt data=/Users/bw/Documents/Hachathons/ROS2026/top_view_toys/data.yaml
# Out:
# /Users/bw/Documents/Hachathons/ROS2026
# Ultralytics 8.4.23 🚀 Python-3.12.10 torch-2.10.0 CPU (Apple M1)
# Model summary (fused): 93 layers, 25,843,234 parameters, 0 gradients, 78.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1226.2±50.3 MB/s, size: 1001.9 KB)
# val: Scanning /Users/bw/Documents/Hachathons/ROS2026/top_view_toys/labels/val.cache... 2 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2/2 932.1Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 7.2it/s 0.1s
#                    all          2         24      0.942      0.962      0.995      0.683
#                Octopus          2          4      0.961          1      0.995      0.677
#           Red cylinder          2          4          1      0.823      0.995      0.742
#            blue square          2          4      0.945          1      0.995      0.705
# ...

# %%
# %cd {HOME}

# !yolo task=detect mode=predict model=/Users/bw/Documents/Hachathons/ROS2026/runs/detect/train19/weights/best.pt conf=0.5 source="/Users/bw/Documents/Hachathons/ROS2026/top_view_toys/images/val/2a7ee168-1774097513.png"
# Out:
# /Users/bw/Documents/Hachathons/ROS2026
# Ultralytics 8.4.23 🚀 Python-3.12.10 torch-2.10.0 CPU (Apple M1)
# Model summary (fused): 93 layers, 25,843,234 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/1 /Users/bw/Documents/Hachathons/ROS2026/top_view_toys/images/val/2a7ee168-1774097513.png: 224x160 2 Octopuss, 1 Red cylinder, 2 blue squares, 2 bunnys, 2 pinguins, 2 red squares, 33.1ms
# Speed: 0.5ms preprocess, 33.1ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 160)
# Results saved to /Users/bw/Documents/Hachathons/ROS2026/runs/detect/predict20
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}

# !yolo task=detect mode=predict model=/Users/bw/Documents/Hachathons/ROS2026/runs/detect/train16/weights/best.pt conf=0.7 source="/Users/bw/Documents/Hachathons/ROS2026/test_no_learning.png"
# Out:
# /Users/bw/Documents/Hachathons/ROS2026
# Ultralytics 8.4.23 🚀 Python-3.12.10 torch-2.10.0 CPU (Apple M1)
# Model summary (fused): 93 layers, 25,840,339 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/1 /Users/bw/Documents/Hachathons/ROS2026/test_no_learning.png: 128x96 1 Good, 19.9ms
# Speed: 0.3ms preprocess, 19.9ms inference, 0.4ms postprocess per image at shape (1, 3, 128, 96)
# Results saved to /Users/bw/Documents/Hachathons/ROS2026/runs/detect/predict17
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}

# !yolo task=classify mode=train model=yolov8m-cls.pt data=/Users/bw/Documents/Hachathons/ROS2026/classification_dataset epochs=10 imgsz=120
# Out:
# /Users/bw/Documents/Hachathons/ROS2026
# New https://pypi.org/project/ultralytics/8.4.24 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.23 🚀 Python-3.12.10 torch-2.10.0 CPU (Apple M1)
# ...

# %%
# %cd {HOME}

# !yolo task=classify mode=val model=/Users/bw/Documents/Hachathons/ROS2026/runs/classify/train7/weights/best.pt data=/Users/bw/Documents/Hachathons/ROS2026/classification_dataset
# Out:
# Ultralytics 8.4.23 🚀 Python-3.12.10 torch-2.10.0 CPU (Apple M1)
# YOLOv8m-cls summary (fused): 42 layers, 15,771,623 parameters, 0 gradients, 41.6 GFLOPs
# train: /Users/bw/Documents/Hachathons/ROS2026/classification_dataset/train... found 392 images in 7 classes ✅
# val: /Users/bw/Documents/Hachathons/ROS2026/classification_dataset/val... found 60 images in 7 classes ✅
# test: /Users/bw/Documents/Hachathons/ROS2026/classification_dataset/test... found 46 images in 7 classes ✅
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 638.8±169.9 MB/s, size: 17.1 KB)
# val: Scanning /Users/bw/Documents/Hachathons/ROS2026/classification_dataset/val... 60 images, 0 corrupt: 100% ━━━━━━━━━━━━ 60/60 31.5Mit/s 0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 2.1it/s 1.9s0.9s
#                    all          1          1
# Speed: 0.0ms preprocess, 29.7ms inference, 0.0ms loss, 0.0ms postprocess per image
# ...

# %%
# %cd {HOME}

# !yolo task=classify mode=predict model=/Users/bw/Documents/Hachathons/ROS2026/runs/classify/train7/weights/best.pt conf=0.5 source="/Users/bw/Documents/Hachathons/ROS2026/classification_dataset/val/Octopus/1ffdfc23-1774106735_0.png"
# Out:
# /Users/bw/Documents/Hachathons/ROS2026
# Ultralytics 8.4.23 🚀 Python-3.12.10 torch-2.10.0 CPU (Apple M1)
# YOLOv8m-cls summary (fused): 42 layers, 15,771,623 parameters, 0 gradients, 41.6 GFLOPs
#
# image 1/1 /Users/bw/Documents/Hachathons/ROS2026/classification_dataset/val/Octopus/1ffdfc23-1774106735_0.png: 128x128 Octopus 1.00, Cylinder 0.00, Penguin 0.00, Bunny 0.00, Aruco 0.00, 11.7ms
# Speed: 4.0ms preprocess, 11.7ms inference, 0.1ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to /Users/bw/Documents/Hachathons/ROS2026/runs/classify/predict6
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
